# %%
df = pd.read_csv('C:/Users/user/Downloads/FoodBalanceSheets_E_Africa_NOFLAG_new.csv',encoding='latin-1')

# %%
df.head()
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %% [markdown]
# **Q11** Answer the following questions based on the African food production dataset provided by the FAO website already provided
#
# What is the total sum of Animal Fat produced in 2014 and 2017 respectively? Hint: Perform a groupby sum aggregation on ‘Item’

# %%
df_new=df[['Item','Y2014','Y2017']]
df_new.groupby(['Item']).sum()
# Out:
#                          Y2014      Y2017
# Item
# Alcohol, Non-Food      2403.00    2348.00
# Alcoholic Beverages  102410.11   95581.06
# Animal Products       11935.65   11547.65
# Animal fats          209460.54  269617.53
# Apples and products    9499.23   10198.90
# ...                        ...        ...
# Vegetables, Other    155038.96  157752.59
# Vegetal Products     107145.19  107655.20
# Wheat and products   232670.13  240047.62
# Wine                   4497.36    4178.02
# Yams                 200396.96  229174.59
#
# [119 rows x 2 columns]

# %% [markdown]
# **Q12** What is the mean and standard deviation across the whole dataset for the year 2015 to 3 decimal places?

# %%
print('Mean:',round(df['Y2015'].mean(),3))
print('Standard Deviation:',round(df['Y2015'].std(),3))
# Out:
# Mean: 135.236
# Standard Deviation: 1603.404

# %% [markdown]
# **Q13** What is the total number and percentage of missing data in 2016 to 2 decimal places?

# %%
total = df['Y2016'].count()

# %%
null_counts = df['Y2016'].isnull().sum()
print("Total nulls:",null_counts)
# Out:
# Total nulls: 1535

# %% [markdown]
# **Q14** Which year had the highest correlation with ‘Element Code’?
#
#  >Ans: Its 2014

# %%
df.corr()
# Out:
#               Area Code  Item Code  Element Code     Y2014     Y2015  \
# Area Code      1.000000  -0.005159     -0.000209  0.006164  0.005472
# Item Code     -0.005159   1.000000     -0.024683  0.021722  0.020857
# Element Code  -0.000209  -0.024683      1.000000  0.024457  0.023889
# Y2014          0.006164   0.021722      0.024457  1.000000  0.994647
# Y2015          0.005472   0.020857      0.023889  0.994647  1.000000
# Y2016          0.005247   0.020109      0.023444  0.996081  0.995739
# Y2017          0.005006   0.021494      0.024254  0.995230  0.988048
# Y2018          0.005665   0.021314      0.024279  0.994872  0.988208
#
#                  Y2016     Y2017     Y2018
# Area Code     0.005247  0.005006  0.005665
# Item Code     0.020109  0.021494  0.021314
# Element Code  0.023444  0.024254  0.024279
# Y2014         0.996081  0.995230  0.994872
# Y2015         0.995739  0.988048  0.988208
# Y2016         1.000000  0.992785  0.992757
# ...

# %% [markdown]
# Q15
# What year has the highest sum of Import Quantity?
#
# Hint- Perform a groupby operation on ‘Element’ and use the resulting Dataframe to answer the question
#
#
# > Ans 2017

# %%
df.groupby(['Element']).sum()
# Out:
#                                         Area Code  Item Code  Element Code  \
# Element
# Domestic supply quantity                   708993   14197445      28068795
# Export Quantity                            599910   11840553      26026133
# Fat supply quantity (g/capita/day)         675050   13535000       3435732
# Feed                                       176272    3538507       7282199
# Food                                       663295   13285035      25406622
# Food supply (kcal/capita/day)              674057   13511060       3329296
# Food supply quantity (kg/capita/yr)        658446   13185401       3163725
# Import Quantity                            688174   13795966      28834929
# Losses                                     274353    5424803      10292107
# Other uses (non-food)                      235554    4729749       8926728
# Processing                                 271940    5350416      10313310
# ...

# %% [markdown]
# **Q16** What is the total number of the sum of Production in 2014?
#
# Hint- Perform a groupby operation on ‘Element’ and use the resulting Dataframe to answer the question
#
# >Ans 1931287.75

# %%
df.groupby(['Element']).sum()
# Out:
#                                         Area Code  Item Code  Element Code  \
# Element
# Domestic supply quantity                   708993   14197445      28068795
# Export Quantity                            599910   11840553      26026133
# Fat supply quantity (g/capita/day)         675050   13535000       3435732
# Feed                                       176272    3538507       7282199
# Food                                       663295   13285035      25406622
# Food supply (kcal/capita/day)              674057   13511060       3329296
# Food supply quantity (kg/capita/yr)        658446   13185401       3163725
# Import Quantity                            688174   13795966      28834929
# Losses                                     274353    5424803      10292107
# Other uses (non-food)                      235554    4729749       8926728
# Processing                                 271940    5350416      10313310
# ...

# %% [markdown]
# **Q17** Which of these elements had the highest sum in 2018?
#
# Hint-  Select columns ‘Y2018’ and ‘Element’, Perform a groupby operation on ‘Element’ on the selected dataframe and answer the  question.
#
# >Ans Domestic supply quantity

# %%
temp = df[['Element','Y2018']]
temp
# Out:
#                                       Element     Y2018
# 0               Total Population - Both sexes  42228.00
# 1                    Domestic supply quantity      0.00
# 2               Food supply (kcal/capita/day)   3322.00
# 3      Protein supply quantity (g/capita/day)     91.83
# 4          Fat supply quantity (g/capita/day)     77.28
# ...                                       ...       ...
# 60938                                    Food     16.00
# 60939     Food supply quantity (kg/capita/yr)      1.08
# 60940           Food supply (kcal/capita/day)      1.00
# 60941  Protein supply quantity (g/capita/day)      0.04
# 60942      Fat supply quantity (g/capita/day)      0.01
#
# [60943 rows x 2 columns]

# %%
temp.groupby('Element').sum()
# Out:
#                                              Y2018
# Element
# Domestic supply quantity                2161192.10
# Export Quantity                          181594.80
# Fat supply quantity (g/capita/day)        10258.69
# Feed                                     233489.68
# Food                                    1303841.28
# Food supply (kcal/capita/day)            455261.00
# Food supply quantity (kg/capita/yr)       49056.85
# Import Quantity                          287997.09
# Losses                                   163902.00
# Other uses (non-food)                     91300.97
# Processing                               308429.00
# Production                              2075072.89
# Protein supply quantity (g/capita/day)    11833.56
# Residuals                                 34864.00
# Seed                                      25263.14
# Stock Variation                           20577.91
# Total Population - Both sexes           1140605.00
# ...

# %% [markdown]
# **Q18**Which of these elements had the 3rd lowest sum in 2018?
#
# Hint-  Select columns ‘Y2018’ and ‘Element’, Perform a groupby operation on ‘Element’ on the selected dataframe and answer the  question.
# > Protein suppy

# %%
new_temp =temp.groupby('Element').sum()

# %%
new_temp
# Out:
#                                              Y2018
# Element
# Domestic supply quantity                2161192.10
# Export Quantity                          181594.80
# Fat supply quantity (g/capita/day)        10258.69
# Feed                                     233489.68
# Food                                    1303841.28
# Food supply (kcal/capita/day)            455261.00
# Food supply quantity (kg/capita/yr)       49056.85
# Import Quantity                          287997.09
# Losses                                   163902.00
# Other uses (non-food)                     91300.97
# Processing                               308429.00
# Production                              2075072.89
# Protein supply quantity (g/capita/day)    11833.56
# Residuals                                 34864.00
# Seed                                      25263.14
# Stock Variation                           20577.91
# Total Population - Both sexes           1140605.00
# ...

# %% [markdown]
# **Q19**What is the total Import Quantity in Algeria in 2018?
# > Ans 36238.29

# %%
df[df['Area']=="Algeria"].groupby('Element').sum()
# Out:
#                                         Area Code  Item Code  Element Code  \
# Element
# Domestic supply quantity                      464     311204        614916
# Export Quantity                               392     264011        579278
# Fat supply quantity (g/capita/day)            432     291489         73872
# Feed                                           88      58967        121462
# Food                                          420     282744        539910
# Food supply (kcal/capita/day)                 432     291489         71712
# Food supply quantity (kg/capita/yr)           420     282744         67725
# Import Quantity                               448     301030        628432
# Losses                                        208     139857        266396
# Other uses (non-food)                         148     101269        190698
# Processing                                    140      93537        179585
# ...

# %%
**Q2** What is the total number of unique countries in the dataset?

df['Area'].nunique()
# Out:
# Object `dataset` not found.
# 49
